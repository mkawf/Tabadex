# %% [markdown]
# <a href="https://colab.research.google.com/github/mkawf/Tabadex/blob/main/colab_Tabadex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google-generativeai

# %%
import google.generativeai as genai

API_KEY = "AIzaSyDEbvlgYq4WSyOhHzBS_6uqvr4CUf_pv78"

genai.configure(api_key=API_KEY)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os

# لیست مسیرهای پوشه و فایل‌ها
paths = [
    "tabadex-bot/tabadex_bot/__init__.py",
    "tabadex-bot/tabadex_bot/main.py",
    "tabadex-bot/tabadex_bot/config.py",
    "tabadex-bot/tabadex_bot/keyboards.py",
    "tabadex-bot/tabadex_bot/locales.py",
    "tabadex-bot/tabadex_bot/database/__init__.py",
    "tabadex-bot/tabadex_bot/database/models.py",
    "tabadex-bot/tabadex_bot/database/session.py",
    "tabadex-bot/tabadex_bot/database/crud.py",
    "tabadex-bot/tabadex_bot/handlers/__init__.py",
    "tabadex-bot/tabadex_bot/handlers/start_handler.py",
    "tabadex-bot/tabadex_bot/handlers/main_menu_handler.py",
    "tabadex-bot/tabadex_bot/handlers/exchange_handler.py",
    "tabadex-bot/tabadex_bot/handlers/account_handler.py",
    "tabadex-bot/tabadex_bot/handlers/support_handler.py",
    "tabadex-bot/tabadex_bot/handlers/admin/__init__.py",
    "tabadex-bot/tabadex_bot/handlers/admin/panel_handler.py",
    "tabadex-bot/tabadex_bot/handlers/admin/user_management.py",
    "tabadex-bot/tabadex_bot/utils/__init__.py",
    "tabadex-bot/tabadex_bot/utils/decorators.py",
    "tabadex-bot/locales/en.json",
    "tabadex-bot/locales/fa.json",
    "tabadex-bot/.env.example",
    "tabadex-bot/Dockerfile",
    "tabadex-bot/docker-compose.yml",
    "tabadex-bot/requirements.txt",
    "tabadex-bot/README.md",
]

# ساخت پوشه‌ها و فایل‌ها
for path in paths:
    folder = os.path.dirname(path)
    os.makedirs(folder, exist_ok=True)
    with open(path, 'w', encoding='utf-8') as f:
        pass  # فایل خالی می‌سازیم

print("✅ ساختار پروژه ساخته شد!")
# Out:
# ✅ ساختار پروژه ساخته شد!

# %%
# !zip -r tabadex-bot.zip tabadex_bot
# Out:
#   adding: tabadex_bot/ (stored 0%)
#   adding: tabadex_bot/Dockerfile (deflated 42%)
#   adding: tabadex_bot/.ipynb_checkpoints/ (stored 0%)
#   adding: tabadex_bot/README.md (stored 0%)
#   adding: tabadex_bot/.env.example (stored 0%)
#   adding: tabadex_bot/locales/ (stored 0%)
#   adding: tabadex_bot/locales/en.json (deflated 66%)
#   adding: tabadex_bot/locales/fa.json (deflated 70%)
#   adding: tabadex_bot/requirements.txt (deflated 17%)
#   adding: tabadex_bot/__init__.py (stored 0%)
#   adding: tabadex_bot/docker-compose.yml (deflated 49%)
#   adding: tabadex_bot/.env (stored 0%)
#   adding: tabadex_bot/tabadex_bot/ (stored 0%)
#   adding: tabadex_bot/tabadex_bot/keyboards.py (deflated 81%)
#   adding: tabadex_bot/tabadex_bot/utils/ (stored 0%)
#   adding: tabadex_bot/tabadex_bot/utils/decorators.py (deflated 52%)
#   adding: tabadex_bot/tabadex_bot/utils/.ipynb_checkpoints/ (stored 0%)
#   adding: tabadex_bot/tabadex_bot/utils/swapzone_api.py (deflated 69%)
# ...

# %%
from google.colab import files
files.download('tabadex-bot.zip')
